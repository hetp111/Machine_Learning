# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons

X, Y = make_moons(n_samples=1000,shuffle=True,noise=0.2,random_state=1)

plt.scatter(X[:,0],X[:,1],c=Y)
plt.show()

# %%
def sigmoid(z):
    return 1.0/(1.0+np.exp(-z))

# %%
def predict(X, weights):
    return sigmoid(np.dot(X,weights))

# %%
def loss(X, Y, weights):
    Y_ = predict(X, weights)
    cost = np.mean(-Y*np.log(Y_)-(1.0-Y)*np.log(1.0-Y_))
    return cost

# %%
def update(X, Y, weights, learning_rate):
    Y_ = predict(X, weights)
    dw = np.dot(X.T, Y_ - Y)
    m = X.shape[0]
    weights = weights - learning_rate*dw/(float(m))
    return weights

# %%
def train(X, Y, learning_rate=0.5, maxEpochs=1000):
    ones = np.ones((X.shape[0],1))
    X = np.hstack([ones,X])
    weights = np.zeros(X.shape[1])

    for epoch in range(maxEpochs):
        weights = update(X, Y, weights, learning_rate)
        if(epoch%10==0):
            print('Epoch:',epoch,'Loss:',loss(X, Y, weights))
    
    return weights

# %%
weights = train(X,Y)
# Out:
# Epoch: 0 Loss: 0.648066443507481
# Epoch: 10 Loss: 0.457521111084274
# Epoch: 20 Loss: 0.4005054704674935
# Epoch: 30 Loss: 0.37293385933948864
# Epoch: 40 Loss: 0.3562129892717362
# Epoch: 50 Loss: 0.34472087621141445
# Epoch: 60 Loss: 0.33621751060921146
# Epoch: 70 Loss: 0.32963092554827805
# Epoch: 80 Loss: 0.32437452699249797
# Epoch: 90 Loss: 0.32009284125565524
# Epoch: 100 Loss: 0.3165529836588023
# Epoch: 110 Loss: 0.31359312793360744
# Epoch: 120 Loss: 0.31109577633722973
# Epoch: 130 Loss: 0.3089727899353328
# Epoch: 140 Loss: 0.30715642189370396
# Epoch: 150 Loss: 0.3055936242770037
# Epoch: 160 Loss: 0.3042422512367847
# Epoch: 170 Loss: 0.30306842302829634
# Epoch: 180 Loss: 0.3020446362353052
# Epoch: 190 Loss: 0.3011483742530066
# Epoch: 200 Loss: 0.30036106505016097
# Epoch: 210 Loss: 0.2996672869209279
# Epoch: 220 Loss: 0.2990541553675862
# Epoch: 230 Loss: 0.29851084468658085
# Epoch: 240 Loss: 0.2980282111983086
# Epoch: 250 Loss: 0.2975984940985394
# Epoch: 260 Loss: 0.2972150761889582
# Epoch: 270 Loss: 0.2968722912066676
# Epoch: 280 Loss: 0.29656526770179126
# Epoch: 290 Loss: 0.2962898017841382
# Epoch: 300 Loss: 0.29604225282328334
# Epoch: 310 Loss: 0.2958194575109534
# Epoch: 320 Loss: 0.2956186586983024
# Epoch: 330 Loss: 0.2954374461871668
# Epoch: 340 Loss: 0.2952737072438902
# Epoch: 350 Loss: 0.2951255850606108
# Epoch: 360 Loss: 0.294991443744265
# Epoch: 370 Loss: 0.2948698386918839
# Epoch: 380 Loss: 0.29475949142996133
# Epoch: 390 Loss: 0.29465926816920124
# Epoch: 400 Loss: 0.2945681614640365
# Epoch: 410 Loss: 0.29448527447671663
# Epoch: 420 Loss: 0.29440980743446243
# Epoch: 430 Loss: 0.2943410459397638
# Epoch: 440 Loss: 0.2942783508519212
# Epoch: 450 Loss: 0.2942211495051613
# Epoch: 460 Loss: 0.2941689280672634
# Epoch: 470 Loss: 0.2941212248743121
# Epoch: 480 Loss: 0.2940776246032884
# Epoch: 490 Loss: 0.2940377531657867
# Epoch: 500 Loss: 0.29400127322404546
# Epoch: 510 Loss: 0.2939678802453866
# Epoch: 520 Loss: 0.29393729902360655
# Epoch: 530 Loss: 0.2939092806062954
# Epoch: 540 Loss: 0.29388359957583166
# Epoch: 550 Loss: 0.293860051639194
# Epoch: 560 Loss: 0.2938384514879814
# Epoch: 570 Loss: 0.2938186308953354
# Epoch: 580 Loss: 0.2938004370209642
# Epoch: 590 Loss: 0.29378373089930826
# Epoch: 600 Loss: 0.29376838608916916
# Epoch: 610 Loss: 0.293754287465936
# Epoch: 620 Loss: 0.29374133013995457
# Epoch: 630 Loss: 0.293729418486664
# Epoch: 640 Loss: 0.2937184652759147
# Epoch: 650 Loss: 0.2937083908894301
# Epoch: 660 Loss: 0.29369912261671605
# Epoch: 670 Loss: 0.29369059402088205
# Epoch: 680 Loss: 0.29368274436685393
# Epoch: 690 Loss: 0.29367551810533526
# Epoch: 700 Loss: 0.29366886440664436
# Epoch: 710 Loss: 0.2936627367392267
# Epoch: 720 Loss: 0.2936570924882305
# Epoch: 730 Loss: 0.2936518926100475
# Epoch: 740 Loss: 0.2936471013191791
# Epoch: 750 Loss: 0.2936426858041817
# Epoch: 760 Loss: 0.29363861596979957
# Epoch: 770 Loss: 0.29363486420270546
# Epoch: 780 Loss: 0.2936314051585386
# Epoch: 790 Loss: 0.2936282155681787
# Epoch: 800 Loss: 0.29362527406140326
# Epoch: 810 Loss: 0.2936225610062737
# Epoch: 820 Loss: 0.29362005836275695
# Epoch: 830 Loss: 0.29361774954924946
# Epoch: 840 Loss: 0.2936156193207969
# Epoch: 850 Loss: 0.29361365365792763
# Epoch: 860 Loss: 0.29361183966512394
# Epoch: 870 Loss: 0.2936101654780501
# Epoch: 880 Loss: 0.2936086201787412
# Epoch: 890 Loss: 0.29360719371803773
# Epoch: 900 Loss: 0.2936058768446129
# Epoch: 910 Loss: 0.29360466104000726
# Epoch: 920 Loss: 0.29360353845913745
# Epoch: 930 Loss: 0.2936025018757979
# Epoch: 940 Loss: 0.29360154463271615
# Epoch: 950 Loss: 0.293600660595767
# Epoch: 960 Loss: 0.29359984411198264
# Epoch: 970 Loss: 0.29359908997103334
# Epoch: 980 Loss: 0.2935983933698792
# Epoch: 990 Loss: 0.29359774988032256

# %%
def getPredictions(X_Test, weights, labels=True):
    if X_Test.shape[0]!=weights.shape[0]:
        ones = np.ones((X_Test.shape[0],1))
        X_Test = np.hstack([ones,X_Test])

    probs = predict(X_Test, weights)
    if not labels:
        return probs
    else:
        labels = np.zeros(probs.shape)
        labels[probs>=0.5] = 1
        return labels

# %%
x1 = np.linspace(-2,2,10)
x2 = -(weights[0]+weights[1]*x1)/weights[2]

# %%
plt.scatter(X[:,0],X[:,1],c=Y)
plt.plot(x1,x2)
plt.show()

# %%
Y_ = getPredictions(X,weights,labels=True)
training_acc = np.sum(Y_==Y)/Y.shape[0]
print(training_acc)
# Out:
# 0.869
